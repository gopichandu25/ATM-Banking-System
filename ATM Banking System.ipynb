# %%
# ATM

username='Kavya'
password='93467'

c_name=input("Enter your name: ")
c_pass=str(input("Enter your passwoord: "))

amount= 5000

if c_name==username and c_pass==password:
    while True:
        print('''
        1.Deposit
        2.Withdraw
        3.Ministatement
        4.Exit
        ''')
        option=int(input("Select your Option: "))
        if option==1:
            deposit=int(input("Enter the Amount: "))
            amount+=deposit
            print("Total Amount: ",amount)
        elif option==2:
            withdraw=int(input("Enter the Amount: "))
            if withdraw<=amount:
                amount-=withdraw
                print("Total Amount: ",amount)
            else:
                print("Insuffient Balance")
        elif option==3:
            print("=======ATM=======")
            print("Username: ",username)
            print("Total Amount: ",amount)
            print("Thanks for Visiting")
            print("==================")
        elif option==4:
            print("Thanks for Visiting!")
            break
        else:
            print("Invalid Option")
else:
    print("Please Enter Correct Logins")
# Out:
# Enter your name:  Kavya
# Enter your passwoord:  93467
#         1.Deposit
#         2.Withdraw
#         3.Ministatement
#         4.Exit
# Select your Option:  1
# Enter the Amount:  2000
# Total Amount:  7000
#
#         1.Deposit
#         2.Withdraw
#         3.Ministatement
#         4.Exit
# Select your Option:  2
# Enter the Amount:  1000
# Total Amount:  6000
#
#         1.Deposit
#         2.Withdraw
#         3.Ministatement
#         4.Exit
